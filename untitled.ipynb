# %%
import numpy as np

class HfO2_Simulator:
    def __init__(self, lp=2.4, ld=-2.1, bits=6):
        # NeuroSim 3.0 표준 HfO2 파라미터 (단위: Siemens)
        self.g_max = 100e-6 
        self.g_min = 1e-6
        self.lp = lp  # 증가 시 비선형성
        self.ld = ld  # 감소 시 비선형성
        self.levels = 2 ** bits # 64 levels
        
        # 64개의 불연속적인 상태(State) 생성
        self.states = np.linspace(0, 1, self.levels)
        self.lut_p = self._calc_g(self.states, self.lp)
        self.lut_d = self._calc_g(self.states, self.ld)

    def _calc_g(self, p, alpha):
        if alpha == 0: return self.g_min + (self.g_max - self.g_min) * p
        return self.g_min + (self.g_max - self.g_min) * (1 - np.exp(-alpha * p)) / (1 - np.exp(-alpha))

    def apply_device_constraints(self, weight):
        """수학적 가중치(0~1)를 실제 소자가 가질 수 있는 전도도로 변환"""
        # 1. 0~1 사이로 정규화된 가중치를 전도도 범위로 확장
        target_g = self.g_min + (self.g_max - self.g_min) * weight
        
        # 2. 64단계 중 가장 가까운 물리적 상태 찾기 (Resolution 한계 반영)
        idx = np.argmin(np.abs(self.lut_p - target_g))
        real_g = self.lut_p[idx]
        
        # 3. 다시 가중치 형태(0~1)로 복원하여 모델에 적용
        return (real_g - self.g_min) / (self.g_max - self.g_min)

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from spikingjelly.activation_based import neuron, layer, functional, surrogate

# 1. NeuroSim HfO2 파라미터 (Cell.cpp 수치 반영)
class HfO2_RRAM:
    NL_LTP = 2.4
    NL_LTD = -4.88
    STEPS = 100
    SIGMA = 0.035

# 2. 고도화된 차동 시냅스 엔진 (초기 발화율 확보)
class NeuroSim_Synapse:
    def __init__(self, shape, device):
        self.device = device
        # [핵심 수정] 초기 가중치가 0이 되지 않도록 G_pos와 G_neg에 차이를 둠
        # 알고리즘상의 Kaiming Normal 분포를 물리적 공간([0.1, 0.9])에 매핑
        init_w = torch.randn(shape, device=device) * 0.1
        self.g_pos = torch.clamp(0.5 + (init_w / 2.0), 0.1, 0.9)
        self.g_neg = torch.clamp(0.5 - (init_w / 2.0), 0.1, 0.9)

    def get_weight(self):
        # 가중치 스케일을 키워 뉴런이 발화할 수 있게 함 (Scale factor 5.0)
        return (self.g_pos - self.g_neg) * 5.0

    def update_physics(self, delta_w):
        with torch.no_grad():
            # 변화량에 따라 업데이트 방향 결정 (임계값 완화 0.001)
            mask_p = delta_w > 0.001
            mask_d = delta_w < -0.001

            # NeuroSim NonlinearWeight 공식 적용
            if mask_p.any():
                self.g_pos[mask_p] += (1.0 / HfO2_RRAM.STEPS) * torch.exp(-HfO2_RRAM.NL_LTP * self.g_pos[mask_p])
            if mask_d.any():
                self.g_neg[mask_d] += (1.0 / HfO2_RRAM.STEPS) * torch.exp(-HfO2_RRAM.NL_LTP * self.g_neg[mask_d])

            # 노이즈 및 클리핑
            noise = torch.randn_like(self.g_pos) * HfO2_RRAM.SIGMA
            self.g_pos = torch.clamp(self.g_pos + noise, 0.01, 0.99)
            self.g_neg = torch.clamp(self.g_neg + noise, 0.01, 0.99)

# 3. 모델 정의
class RealisticSNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            layer.Flatten(),
            layer.Linear(784, 100, bias=False),
            neuron.LIFNode(tau=2.0, surrogate_function=surrogate.Sigmoid(), detach_reset=True),
            layer.Linear(100, 10, bias=False),
            neuron.LIFNode(tau=2.0, surrogate_function=surrogate.Sigmoid(), detach_reset=True)
        )
    def forward(self, x): return self.model(x)

# 4. 분석 실행
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# 데이터 정규화 강화 (0.5 평균)
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
train_loader = DataLoader(datasets.MNIST('./data', train=True, download=True, transform=transform), batch_size=128, shuffle=True)
test_loader = DataLoader(datasets.MNIST('./data', train=False, transform=transform), batch_size=128)

model = RealisticSNN().to(device)
syn_fc1 = NeuroSim_Synapse(model.model[1].weight.shape, device)
syn_fc2 = NeuroSim_Synapse(model.model[3].weight.shape, device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

acc_history = []
T = 8

print(f"Starting Final Analysis on {device}...")

for epoch in range(5):
    model.train()
    for img, label in train_loader:
        img, label = img.to(device), label.to(device)
        
        # 1. 현재 물리적 가중치 동기화
        model.model[1].weight.data = syn_fc1.get_weight()
        model.model[3].weight.data = syn_fc2.get_weight()
        
        # 2. 순전파 및 역전파
        optimizer.zero_grad()
        out_fr = 0
        for t in range(T): out_fr += model(img)
        loss = criterion(out_fr / T, label)
        loss.backward()
        
        # 3. 가상 업데이트 수행
        optimizer.step()
        
        # 4. 가상 가중치와의 차이를 물리적 펄스로 반영
        with torch.no_grad():
            syn_fc1.update_physics(model.model[1].weight.data - syn_fc1.get_weight())
            syn_fc2.update_physics(model.model[3].weight.data - syn_fc2.get_weight())
        
        functional.reset_net(model)

    # 평가
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for img, label in test_loader:
            img, label = img.to(device), label.to(device)
            out_fr = 0
            for t in range(T): out_fr += model(img)
            correct += (out_fr.argmax(1) == label).sum().item()
            total += label.size(0)
            functional.reset_net(model)
    
    acc = correct / total
    acc_history.append(acc)
    print(f"Epoch {epoch+1}: Accuracy = {acc:.4f}")

plt.plot(range(1, 6), acc_history, 'bo-', label='HfO2 Differential RRAM')
plt.ylabel('Accuracy'); plt.xlabel('Epoch'); plt.legend(); plt.show()
# Out:
# Starting Final Analysis on cuda...
# Epoch 1: Accuracy = 0.7564
# Epoch 2: Accuracy = 0.8234
# Epoch 3: Accuracy = 0.6933
# Epoch 4: Accuracy = 0.7441
# Epoch 5: Accuracy = 0.6779

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from spikingjelly.activation_based import neuron, layer, functional, surrogate

# 1. HfO2 RRAM 물리 파라미터 (고정)
class HfO2_Physics:
    NL_LTP = 2.4
    NL_LTD = -4.88
    STEPS = 100
    SIGMA = 0.035

# 2. 장기 수렴을 위해 '센터링'이 강화된 시냅스 엔진
class Robust_Synapse:
    def __init__(self, shape, device):
        self.device = device
        # 검증된 초기화 로직 유지
        self.g_pos = torch.full(shape, 0.55, device=device) + torch.randn(shape, device=device) * 0.03
        self.g_neg = torch.full(shape, 0.45, device=device) + torch.randn(shape, device=device) * 0.03
        
        # [조정] LTD 보정을 더 보수적으로 (0.25)
        self.comp_factor = 0.25 
        # 가중치 포화 방지를 위한 미세 복원력 (Centering)
        self.leak = 0.0005 

    def get_weight(self):
        # 검증된 신호 세기 유지
        return (self.g_pos - self.g_neg) * 6.5

    def update_physics(self, delta_w):
        with torch.no_grad():
            # [추가] 그레디언트 클리핑: 급격한 가중치 변화 방지
            delta_w = torch.clamp(delta_w, -0.05, 0.05)
            
            mask_p = delta_w > 0.001
            mask_d = delta_w < -0.001

            # LTP/LTD 물리 업데이트
            if mask_p.any():
                self.g_pos[mask_p] += (1.0 / HfO2_Physics.STEPS) * torch.exp(-HfO2_Physics.NL_LTP * self.g_pos[mask_p])
            if mask_d.any():
                # g_neg를 키워 전체 가중치를 낮춤 (LTD 보정 적용)
                self.g_neg[mask_d] += (self.comp_factor / HfO2_Physics.STEPS) * torch.exp(-HfO2_Physics.NL_LTP * self.g_neg[mask_d])

            # [핵심] 가중치 센터링: 0이나 1로 달라붙는 것을 방지
            self.g_pos += (0.5 - self.g_pos) * self.leak
            self.g_neg += (0.5 - self.g_neg) * self.leak

            # 물리적 노이즈 및 가중치 활성 영역(0.05 ~ 0.95) 보호
            noise = torch.randn_like(self.g_pos) * HfO2_Physics.SIGMA
            self.g_pos = torch.clamp(self.g_pos + noise, 0.05, 0.95)
            self.g_neg = torch.clamp(self.g_neg + noise, 0.05, 0.95)

# 3. 모델 정의
class RealisticSNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            layer.Flatten(),
            layer.Linear(784, 100, bias=False),
            neuron.LIFNode(tau=2.0, surrogate_function=surrogate.Sigmoid(), detach_reset=True),
            layer.Linear(100, 10, bias=False),
            neuron.LIFNode(tau=2.0, surrogate_function=surrogate.Sigmoid(), detach_reset=True)
        )
    def forward(self, x): return self.model(x)

# 4. 분석 환경 및 데이터 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
train_loader = DataLoader(datasets.MNIST('./data', train=True, download=True, transform=transform), batch_size=128, shuffle=True)
test_loader = DataLoader(datasets.MNIST('./data', train=False, transform=transform), batch_size=128)

model = RealisticSNN().to(device)
syn1 = Robust_Synapse(model.model[1].weight.shape, device)
syn2 = Robust_Synapse(model.model[3].weight.shape, device)

# 학습률을 0.0008로 소폭 낮추어 안정성 강화
optimizer = torch.optim.Adam(model.parameters(), lr=0.0008)
# 코사인 스케줄러로 에포크 후반부 업데이트를 더 정교하게 제어
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10)
criterion = nn.CrossEntropyLoss()

acc_history = []
T = 8 

print(f"Starting Robust Stability Analysis on {device}...")

# 5. 메인 학습 루프
for epoch in range(10):
    model.train()
    for img, label in train_loader:
        img, label = img.to(device), label.to(device)
        model.model[1].weight.data = syn1.get_weight()
        model.model[3].weight.data = syn2.get_weight()
        
        optimizer.zero_grad()
        out_fr = 0
        for t in range(T): out_fr += model(img)
        loss = criterion(out_fr / T, label)
        loss.backward()
        optimizer.step()
        
        with torch.no_grad():
            syn1.update_physics(model.model[1].weight.data - syn1.get_weight())
            syn2.update_physics(model.model[3].weight.data - syn2.get_weight())
        
        functional.reset_net(model)
    
    scheduler.step()
    
    # 평가
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for img, label in test_loader:
            img, label = img.to(device), label.to(device)
            out_fr = 0
            for t in range(T): out_fr += model(img)
            correct += (out_fr.argmax(1) == label).sum().item()
            total += label.size(0)
            functional.reset_net(model)
    
    acc = correct / total
    acc_history.append(acc)
    print(f"Epoch {epoch+1}: Accuracy = {acc:.4f}, LR = {optimizer.param_groups[0]['lr']:.6f}")

# 결과 시각화
plt.figure(figsize=(8, 5))
plt.plot(range(1, 11), acc_history, 'mo-', label='Robust HfO2 SNN')
plt.title('Final Optimized Accuracy: Preventing Epoch Crash')
plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.grid(True); plt.show()
# Out:
# Starting Robust Stability Analysis on cuda...
# Epoch 1: Accuracy = 0.7150, LR = 0.000780
# Epoch 2: Accuracy = 0.8193, LR = 0.000724
# Epoch 3: Accuracy = 0.8170, LR = 0.000635
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 94
#      92 for epoch in range(10):
#      93     model.train()
# ---> 94     for img, label in train_loader:
#      95         img, label = img.to(device), label.to(device)
#      96         model.model[1].weight.data = syn1.get_weight()
#
# File c:\Users\Syrious\anaconda3\envs\Neuromorph\lib\site-packages\torch\utils\data\dataloader.py:733, in _BaseDataLoaderIter.__next__(self)
#     730 if self._sampler_iter is None:
#     731     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     732     self._reset()  # type: ignore[call-arg]
# --> 733 data = self._next_data()
#     734 self._num_yielded += 1
#     735 if (
#     736     self._dataset_kind == _DatasetKind.Iterable
#     737     and self._IterableDataset_len_called is not None
#     738     and self._num_yielded > self._IterableDataset_len_called
#     739 ):
#
# File c:\Users\Syrious\anaconda3\envs\Neuromorph\lib\site-packages\torch\utils\data\dataloader.py:789, in _SingleProcessDataLoaderIter._next_data(self)
#     787 def _next_data(self):
#     788     index = self._next_index()  # may raise StopIteration
# --> 789     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     790     if self._pin_memory:
#     791         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\Syrious\anaconda3\envs\Neuromorph\lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File c:\Users\Syrious\anaconda3\envs\Neuromorph\lib\site-packages\torch\utils\data\_utils\fetch.py:52, in <listcomp>(.0)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File c:\Users\Syrious\anaconda3\envs\Neuromorph\lib\site-packages\torchvision\datasets\mnist.py:146, in MNIST.__getitem__(self, index)
#     143 img = Image.fromarray(img.numpy(), mode="L")
#     145 if self.transform is not None:
# --> 146     img = self.transform(img)
#     148 if self.target_transform is not None:
#     149     target = self.target_transform(target)
#
# File c:\Users\Syrious\anaconda3\envs\Neuromorph\lib\site-packages\torchvision\transforms\transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File c:\Users\Syrious\anaconda3\envs\Neuromorph\lib\site-packages\torchvision\transforms\transforms.py:137, in ToTensor.__call__(self, pic)
#     129 def __call__(self, pic):
#     130     """
#     131     Args:
#     132         pic (PIL Image or numpy.ndarray): Image to be converted to tensor.
#    (...)
#     135         Tensor: Converted image.
#     136     """
# --> 137     return F.to_tensor(pic)
#
# File c:\Users\Syrious\anaconda3\envs\Neuromorph\lib\site-packages\torchvision\transforms\functional.py:172, in to_tensor(pic)
#     170 if pic.mode == "1":
#     171     img = 255 * img
# --> 172 img = img.view(pic.size[1], pic.size[0], F_pil.get_image_num_channels(pic))
#     173 # put it from HWC to CHW format
#     174 img = img.permute((2, 0, 1)).contiguous()
#
# KeyboardInterrupt:

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from spikingjelly.activation_based import neuron, layer, functional, surrogate

# 1. HfO2 RRAM 물리 특성 설정
class HfO2_Device:
    NL_LTP = 2.4

# 2. 해상도와 레이어 스케일이 독립 제어되는 HAT 레이어
class RRAM_Linear_HAT(nn.Linear):
    def __init__(self, in_features, out_features, res_steps=100):
        super().__init__(in_features, out_features, bias=False)
        self.res_steps = res_steps
        
        # [핵심 수정] 가중치를 소자 가동 범위인 [-0.8, 0.8]에 고르게 배치하여 
        # 어떤 해상도에서도 균일한 격자 샘플링이 일어나도록 유도
        nn.init.uniform_(self.weight, -0.8, 0.8)
        
        # [핵심 수정] 레이어 크기에 맞는 최적의 입력 에너지를 동적으로 계산 (Kaiming 기반 확장)
        # LIF 뉴런이 죽지 않고 가장 민감하게 반응하는 Firing Gain(4.5) 적용
        self.dynamic_scale = np.sqrt(2.0 / in_features) * 4.5

    def apply_physics(self, w):
        w_clipped = torch.clamp(w, -1.0, 1.0)
        
        # 차동 구조 모사 (Positive / Negative 소자 분리)
        w_pos = torch.clamp(w_clipped, min=0)
        w_neg = torch.clamp(-w_clipped, min=0)
        
        # STE(Straight-Through Estimator) 양자화: 정규화된 공간에 해상도 정밀 적용
        w_pos_q = w_pos + (torch.round(w_pos * self.res_steps) / self.res_steps - w_pos).detach()
        w_neg_q = w_neg + (torch.round(w_neg * self.res_steps) / self.res_steps - w_neg).detach()
        
        # HfO2 비선형성 곡선 투영
        w_pos_phys = (1 - torch.exp(-HfO2_Device.NL_LTP * w_pos_q)) / (1 - np.exp(-HfO2_Device.NL_LTP))
        w_neg_phys = (1 - torch.exp(-HfO2_Device.NL_LTP * w_neg_q)) / (1 - np.exp(-HfO2_Device.NL_LTP))
        
        # 물리 연산 종료 후, 레이어별 밸런스를 맞추기 위한 동적 스케일 적용
        return (w_pos_phys - w_neg_phys) * self.dynamic_scale

    def forward(self, x):
        p_weight = self.apply_physics(self.weight)
        return nn.functional.linear(x, p_weight)

# 3. SNN 모델 정의
class HfO2_Quant_SNN(nn.Module):
    def __init__(self, res_steps):
        super().__init__()
        self.model = nn.Sequential(
            layer.Flatten(),
            RRAM_Linear_HAT(784, 128, res_steps=res_steps),
            neuron.LIFNode(tau=2.0, surrogate_function=surrogate.Sigmoid(), detach_reset=True),
            RRAM_Linear_HAT(128, 10, res_steps=res_steps),
            neuron.LIFNode(tau=2.0, surrogate_function=surrogate.Sigmoid(), detach_reset=True)
        )
    def forward(self, x): return self.model(x)

num_operator = 30

# 4. 해상도별 정량 실험 제어 함수
def run_resolution_analysis(res_list):
    from torchvision import datasets, transforms
    from torch.utils.data import DataLoader
    
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
    train_loader = DataLoader(datasets.MNIST('./data', train=True, download=True, transform=transform), batch_size=128, shuffle=True)
    test_loader = DataLoader(datasets.MNIST('./data', train=False, transform=transform), batch_size=128)

    all_results = {}

    for res in res_list:
        print(f"\n--- 분석 시작: Resolution {res} Steps ---")
        model = HfO2_Quant_SNN(res_steps=res).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        criterion = nn.CrossEntropyLoss()
        
        history = []
        for epoch in range(num_operator):
            model.train()
            for img, label in train_loader:
                img, label = img.to(device), label.to(device)
                optimizer.zero_grad()
                
                out_fr = 0
                for t in range(8): out_fr += model(img)
                loss = criterion(out_fr / 8, label)
                loss.backward()
                
                optimizer.step()
                functional.reset_net(model)
            
            # 평가
            model.eval()
            correct, total = 0, 0
            with torch.no_grad():
                for img, label in test_loader:
                    img, label = img.to(device), label.to(device)
                    out_fr = 0
                    for t in range(8): out_fr += model(img)
                    correct += (out_fr.argmax(1) == label).sum().item()
                    total += label.size(0)
                    functional.reset_net(model)
            
            acc = correct / total
            history.append(acc)
            print(f"Epoch {epoch+1}: 정확도 = {acc:.4f}")
        
        all_results[res] = history
    return all_results

# 5. 최종 실험 제어 (8, 16, 64, 256 전 영역 완전 통제 비교)
resolutions = [8, 16, 64, 256]
analysis_data = run_resolution_analysis(resolutions)

plt.figure(figsize=(10, 6))
for res, history in analysis_data.items():
    plt.plot(range(1, num_operator+1), history, marker='o', label=f'Resolution: {res} steps')
plt.title('Quantitative Impact of RRAM Resolution on SNN Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# --- 분석 시작: Resolution 8 Steps ---
# Epoch 1: 정확도 = 0.8418
# Epoch 2: 정확도 = 0.8835
# Epoch 3: 정확도 = 0.8998
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 116
#     114 # 5. 최종 실험 제어 (8, 16, 64, 256 전 영역 완전 통제 비교)
#     115 resolutions = [8, 16, 64, 256]
# --> 116 analysis_data = run_resolution_analysis(resolutions)
#     118 plt.figure(figsize=(10, 6))
#     119 for res, history in analysis_data.items():
#
# Cell In[1], line 88, in run_resolution_analysis(res_list)
#      85 optimizer.zero_grad()
#      87 out_fr = 0
# ---> 88 for t in range(8): out_fr += model(img)
#      89 loss = criterion(out_fr / 8, label)
#      90 loss.backward()
#
# File c:\Users\Syrious\anaconda3\envs\Neuromorph\lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Syrious\anaconda3\envs\Neuromorph\lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# Cell In[1], line 58, in HfO2_Quant_SNN.forward(self, x)
# ---> 58 def forward(self, x): return self.model(x)
#
# File c:\Users\Syrious\anaconda3\envs\Neuromorph\lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Syrious\anaconda3\envs\Neuromorph\lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\Syrious\anaconda3\envs\Neuromorph\lib\site-packages\torch\nn\modules\container.py:240, in Sequential.forward(self, input)
#     238 def forward(self, input):
#     239     for module in self:
# --> 240         input = module(input)
#     241     return input
#
# File c:\Users\Syrious\anaconda3\envs\Neuromorph\lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Syrious\anaconda3\envs\Neuromorph\lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\Syrious\anaconda3\envs\Neuromorph\lib\site-packages\spikingjelly\activation_based\base.py:268, in MemoryModule.forward(self, *args, **kwargs)
#     266 def forward(self, *args, **kwargs):
#     267     if self.step_mode == 's':
# --> 268         return self.single_step_forward(*args, **kwargs)
#     269     elif self.step_mode == 'm':
#     270         return self.multi_step_forward(*args, **kwargs)
#
# File c:\Users\Syrious\anaconda3\envs\Neuromorph\lib\site-packages\spikingjelly\activation_based\neuron.py:907, in LIFNode.single_step_forward(self, x)
#     905 def single_step_forward(self, x: torch.Tensor):
#     906     if self.training:
# --> 907         return super().single_step_forward(x)
#     908     else:
#     909         self.v_float_to_tensor(x)
#
# File c:\Users\Syrious\anaconda3\envs\Neuromorph\lib\site-packages\spikingjelly\activation_based\neuron.py:240, in BaseNode.single_step_forward(self, x)
#     238 self.v_float_to_tensor(x)
#     239 self.neuronal_charge(x)
# --> 240 spike = self.neuronal_fire()
#     241 self.neuronal_reset(spike)
#     242 return spike
#
# File c:\Users\Syrious\anaconda3\envs\Neuromorph\lib\site-packages\spikingjelly\activation_based\neuron.py:177, in BaseNode.neuronal_fire(self)
#     161 def neuronal_fire(self):
#     162     """
#     163     * :ref:`API in English <BaseNode.neuronal_fire-en>`
#     164
#    (...)
#     174     Calculate out spikes of neurons by their current membrane potential and threshold voltage.
#     175     """
# --> 177     return self.surrogate_function(self.v - self.v_threshold)
#
# File c:\Users\Syrious\anaconda3\envs\Neuromorph\lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Syrious\anaconda3\envs\Neuromorph\lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\Syrious\anaconda3\envs\Neuromorph\lib\site-packages\spikingjelly\activation_based\surrogate.py:149, in SurrogateFunctionBase.forward(self, x)
#     147 def forward(self, x: torch.Tensor):
#     148     if self.spiking:
# --> 149         return self.spiking_function(x, self.alpha)
#     150     else:
#     151         return self.primitive_function(x, self.alpha)
#
# File c:\Users\Syrious\anaconda3\envs\Neuromorph\lib\site-packages\spikingjelly\activation_based\surrogate.py:495, in Sigmoid.spiking_function(x, alpha)
#     493 @staticmethod
#     494 def spiking_function(x, alpha):
# --> 495     return sigmoid.apply(x, alpha)
#
# File c:\Users\Syrious\anaconda3\envs\Neuromorph\lib\site-packages\torch\autograd\function.py:575, in Function.apply(cls, *args, **kwargs)
#     572 if not torch._C._are_functorch_transforms_active():
#     573     # See NOTE: [functorch vjp and autograd interaction]
#     574     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 575     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     577 if not is_setup_ctx_defined:
#     578     raise RuntimeError(
#     579         "In order to use an autograd.Function with functorch transforms "
#     580         "(vmap, grad, jvp, jacrev, ...), it must override the setup_context "
#     581         "staticmethod. For more details, please see "
#     582         "https://pytorch.org/docs/main/notes/extending.func.html"
#     583     )
#
# File c:\Users\Syrious\anaconda3\envs\Neuromorph\lib\site-packages\spikingjelly\activation_based\surrogate.py:436, in sigmoid.forward(ctx, x, alpha)
#     434     ctx.save_for_backward(x)
#     435     ctx.alpha = alpha
# --> 436 return heaviside(x)
#
# KeyboardInterrupt:

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from spikingjelly.activation_based import neuron, layer, functional, surrogate

# 1. HfO2 RRAM 물리 특성 설정
class HfO2_Device:
    NL_LTP = 2.4

# 2. 해상도와 레이어 스케일이 독립 제어되는 HAT 레이어
class RRAM_Linear_HAT(nn.Linear):
    def __init__(self, in_features, out_features, res_steps=100):
        super().__init__(in_features, out_features, bias=False)
        self.res_steps = res_steps
        
        nn.init.uniform_(self.weight, -0.8, 0.8)
        self.dynamic_scale = np.sqrt(2.0 / in_features) * 4.5

        # [수정 1] 불변하는 물리 상수를 미리 계산하여 구조적 오버헤드 제거 (math 라이브러리 사용)
        import math
        self.norm_factor = 1.0 - math.exp(-HfO2_Device.NL_LTP)

    def apply_physics(self, w):
        w_clipped = torch.clamp(w, -1.0, 1.0)
        
        w_pos = torch.clamp(w_clipped, min=0)
        w_neg = torch.clamp(-w_clipped, min=0)
        
        w_pos_q = w_pos + (torch.round(w_pos * self.res_steps) / self.res_steps - w_pos).detach()
        w_neg_q = w_neg + (torch.round(w_neg * self.res_steps) / self.res_steps - w_neg).detach()
        
        # [수정 2] np.exp 대신 torch.exp 사용으로 float32 유지 및 GPU 연산 보장
        # [수정 3] 사전 계산된 norm_factor로 연산 최소화
        w_pos_phys = (1.0 - torch.exp(-HfO2_Device.NL_LTP * w_pos_q)) / self.norm_factor
        w_neg_phys = (1.0 - torch.exp(-HfO2_Device.NL_LTP * w_neg_q)) / self.norm_factor
        
        return (w_pos_phys - w_neg_phys) * self.dynamic_scale

    def forward(self, x):
        p_weight = self.apply_physics(self.weight)
        return nn.functional.linear(x, p_weight)

# 3. SNN 모델 정의
class HfO2_Quant_SNN(nn.Module):
    def __init__(self, res_steps):
        super().__init__()
        self.model = nn.Sequential(
            layer.Flatten(),
            RRAM_Linear_HAT(784, 128, res_steps=res_steps),
            neuron.LIFNode(tau=2.0, surrogate_function=surrogate.Sigmoid(), detach_reset=True),
            RRAM_Linear_HAT(128, 10, res_steps=res_steps),
            neuron.LIFNode(tau=2.0, surrogate_function=surrogate.Sigmoid(), detach_reset=True)
        )
    def forward(self, x): return self.model(x)

num_operator = 30

# 4. 해상도별 정량 실험 제어 함수
def run_resolution_analysis(res_list):
    from torchvision import datasets, transforms
    from torch.utils.data import DataLoader
    
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
    train_loader = DataLoader(datasets.MNIST('./data', train=True, download=True, transform=transform), batch_size=128, shuffle=True)
    test_loader = DataLoader(datasets.MNIST('./data', train=False, transform=transform), batch_size=128)

    all_results = {}

    for res in res_list:
        print(f"\n--- 분석 시작: Resolution {res} Steps ---")
        model = HfO2_Quant_SNN(res_steps=res).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        criterion = nn.CrossEntropyLoss()
        
        history = []
        for epoch in range(num_operator):
            model.train()
            for img, label in train_loader:
                img, label = img.to(device), label.to(device)
                optimizer.zero_grad()
                
                out_fr = 0
                for t in range(8): out_fr += model(img)
                loss = criterion(out_fr / 8, label)
                loss.backward()
                
                optimizer.step()
                functional.reset_net(model)
            
            # 평가
            model.eval()
            correct, total = 0, 0
            with torch.no_grad():
                for img, label in test_loader:
                    img, label = img.to(device), label.to(device)
                    out_fr = 0
                    for t in range(8): out_fr += model(img)
                    correct += (out_fr.argmax(1) == label).sum().item()
                    total += label.size(0)
                    functional.reset_net(model)
            
            acc = correct / total
            history.append(acc)
            print(f"Epoch {epoch+1}: 정확도 = {acc:.4f}")
        
        all_results[res] = history
    return all_results

# 5. 최종 실험 제어 (8, 16, 64, 256 전 영역 완전 통제 비교)
resolutions = [8, 16, 64, 256]
analysis_data = run_resolution_analysis(resolutions)

plt.figure(figsize=(10, 6))
for res, history in analysis_data.items():
    plt.plot(range(1, num_operator+1), history, marker='o', label=f'Resolution: {res} steps')
plt.title('Quantitative Impact of RRAM Resolution on SNN Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# --- 분석 시작: Resolution 8 Steps ---
# Epoch 1: 정확도 = 0.7309
# Epoch 2: 정확도 = 0.7694
# Epoch 3: 정확도 = 0.8246
# Epoch 4: 정확도 = 0.8332
# Epoch 5: 정확도 = 0.8401
# Epoch 6: 정확도 = 0.8452
# Epoch 7: 정확도 = 0.8437
# Epoch 8: 정확도 = 0.8462
# Epoch 9: 정확도 = 0.8491
# Epoch 10: 정확도 = 0.8531
# Epoch 11: 정확도 = 0.8542
# Epoch 12: 정확도 = 0.8561
# Epoch 13: 정확도 = 0.8578
# Epoch 14: 정확도 = 0.8584
# Epoch 15: 정확도 = 0.8606
# Epoch 16: 정확도 = 0.8582
# Epoch 17: 정확도 = 0.8613
# Epoch 18: 정확도 = 0.8620
# Epoch 19: 정확도 = 0.8637
# Epoch 20: 정확도 = 0.8619
# Epoch 21: 정확도 = 0.8629
# Epoch 22: 정확도 = 0.8614
# Epoch 23: 정확도 = 0.8623
# Epoch 24: 정확도 = 0.8629
# Epoch 25: 정확도 = 0.8651
# Epoch 26: 정확도 = 0.8640
# Epoch 27: 정확도 = 0.8648
# Epoch 28: 정확도 = 0.8658
# Epoch 29: 정확도 = 0.8661
# Epoch 30: 정확도 = 0.8653
#
# --- 분석 시작: Resolution 16 Steps ---
# Epoch 1: 정확도 = 0.8230
# Epoch 2: 정확도 = 0.8853
# Epoch 3: 정확도 = 0.9037
# Epoch 4: 정확도 = 0.9136
# Epoch 5: 정확도 = 0.9211
# Epoch 6: 정확도 = 0.9246
# Epoch 7: 정확도 = 0.9307
# Epoch 8: 정확도 = 0.9357
# Epoch 9: 정확도 = 0.9375
# Epoch 10: 정확도 = 0.9421
# Epoch 11: 정확도 = 0.9453
# Epoch 12: 정확도 = 0.9462
# Epoch 13: 정확도 = 0.9470
# Epoch 14: 정확도 = 0.9473
# Epoch 15: 정확도 = 0.9497
# Epoch 16: 정확도 = 0.9481
# Epoch 17: 정확도 = 0.9535
# Epoch 18: 정확도 = 0.9524
# Epoch 19: 정확도 = 0.9520
# Epoch 20: 정확도 = 0.9537
# Epoch 21: 정확도 = 0.9561
# Epoch 22: 정확도 = 0.9547
# Epoch 23: 정확도 = 0.9562
# Epoch 24: 정확도 = 0.9553
# Epoch 25: 정확도 = 0.9572
# Epoch 26: 정확도 = 0.9586
# Epoch 27: 정확도 = 0.9569
# Epoch 28: 정확도 = 0.9580
# Epoch 29: 정확도 = 0.9596
# Epoch 30: 정확도 = 0.9602
#
# --- 분석 시작: Resolution 64 Steps ---
# Epoch 1: 정확도 = 0.7156
# Epoch 2: 정확도 = 0.7379
# Epoch 3: 정확도 = 0.8295
# Epoch 4: 정확도 = 0.8397
# Epoch 5: 정확도 = 0.8441
# Epoch 6: 정확도 = 0.8488
# Epoch 7: 정확도 = 0.8494
# Epoch 8: 정확도 = 0.8536
# Epoch 9: 정확도 = 0.9345
# Epoch 10: 정확도 = 0.9392
# Epoch 11: 정확도 = 0.9396
# Epoch 12: 정확도 = 0.9436
# Epoch 13: 정확도 = 0.9435
# Epoch 14: 정확도 = 0.9449
# Epoch 15: 정확도 = 0.9478
# Epoch 16: 정확도 = 0.9486
# Epoch 17: 정확도 = 0.9517
# Epoch 18: 정확도 = 0.9506
# Epoch 19: 정확도 = 0.9499
# Epoch 20: 정확도 = 0.9529
# Epoch 21: 정확도 = 0.9528
# Epoch 22: 정확도 = 0.9525
# Epoch 23: 정확도 = 0.9546
# Epoch 24: 정확도 = 0.9554
# Epoch 25: 정확도 = 0.9526
# Epoch 26: 정확도 = 0.9556
# Epoch 27: 정확도 = 0.9560
# Epoch 28: 정확도 = 0.9555
# Epoch 29: 정확도 = 0.9569
# Epoch 30: 정확도 = 0.9569
#
# --- 분석 시작: Resolution 256 Steps ---
# Epoch 1: 정확도 = 0.8382
# Epoch 2: 정확도 = 0.8873
# Epoch 3: 정확도 = 0.9077
# Epoch 4: 정확도 = 0.9172
# Epoch 5: 정확도 = 0.9215
# Epoch 6: 정확도 = 0.9291
# Epoch 7: 정확도 = 0.9331
# Epoch 8: 정확도 = 0.9345
# Epoch 9: 정확도 = 0.9394
# Epoch 10: 정확도 = 0.9403
# Epoch 11: 정확도 = 0.9452
# Epoch 12: 정확도 = 0.9453
# Epoch 13: 정확도 = 0.9483
# Epoch 14: 정확도 = 0.9475
# Epoch 15: 정확도 = 0.9497
# Epoch 16: 정확도 = 0.9470
# Epoch 17: 정확도 = 0.9507
# Epoch 18: 정확도 = 0.9489
# Epoch 19: 정확도 = 0.9509
# Epoch 20: 정확도 = 0.9521
# Epoch 21: 정확도 = 0.9524
# Epoch 22: 정확도 = 0.9520
# Epoch 23: 정확도 = 0.9524
# Epoch 24: 정확도 = 0.9531
# Epoch 25: 정확도 = 0.9532
# Epoch 26: 정확도 = 0.9537
# Epoch 27: 정확도 = 0.9548
# Epoch 28: 정확도 = 0.9563
# Epoch 29: 정확도 = 0.9569
# Epoch 30: 정확도 = 0.9550
